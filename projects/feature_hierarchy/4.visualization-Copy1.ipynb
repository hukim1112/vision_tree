# %%
import treelib
import numpy as np
import plotly

# %%
class0_L4 = np.load("etching_weights/0-17.npy")
class0_L3 = np.load("etching_weights/0-12.npy")
class0_L2 = np.load("etching_weights/0-7.npy")
class0_L1 = np.load("etching_weights/0-2.npy")
class0 = [class0_L4, class0_L3, class0_L2, class0_L1]

# %%
class1_L4 = np.load("etching_weights/1-17.npy")
class1_L3 = np.load("etching_weights/1-12.npy")
class1_L2 = np.load("etching_weights/1-7.npy")
class1_L1 = np.load("etching_weights/1-2.npy")
class1 = [class1_L4, class1_L3, class1_L2, class1_L1]

# %%
class2_L4 = np.load("etching_weights/2-17.npy")
class2_L3 = np.load("etching_weights/2-12.npy")
class2_L2 = np.load("etching_weights/2-7.npy")
class2_L1 = np.load("etching_weights/2-2.npy")
class2 = [class2_L4, class2_L3, class2_L2, class2_L1]

# %%
class0_L3
# Out:
# array([[0.99091274, 0.99976444, 1.        , 0.9944373 , 1.0014328 ,
#         1.0063604 , 1.        , 1.0011638 , 0.99779636, 0.9962036 ,
#         0.99999994, 0.98508734, 0.9946303 , 0.9912639 , 0.99529845,
#         1.0043876 ],
#        [0.99662465, 1.0027785 , 1.        , 0.9990525 , 1.0042641 ,
#         0.99578077, 1.        , 1.0012847 , 0.99896353, 0.9977363 ,
#         0.99999905, 0.991083  , 0.99547315, 0.99151087, 0.9895568 ,
#         0.99962205],
#        [0.99895245, 1.0009199 , 1.        , 0.99498236, 0.97638476,
#         0.99681115, 1.        , 0.9954166 , 0.996391  , 1.0014778 ,
#         0.99998516, 1.0142651 , 1.0019513 , 1.0048543 , 0.98744446,
#         0.99485195],
#        [1.0021572 , 1.001887  , 1.        , 0.9986631 , 0.98533654,
#         0.9813795 , 1.        , 0.9979749 , 0.9958888 , 0.99888915,
#         0.9999987 , 1.0231056 , 0.99644923, 1.0039716 , 1.0030429 ,
#         0.9968007 ],
#        [1.0012337 , 0.9999308 , 1.        , 0.9834701 , 0.98662466,
#         1.001784  , 1.        , 0.9786159 , 0.9991779 , 0.99173874,
#         0.999991  , 0.9962526 , 0.9841032 , 1.0068886 , 0.9980226 ,
#         1.0132529 ],
#        [0.9992543 , 0.99073863, 1.        , 0.97513163, 0.9649729 ,
#         0.9779505 , 1.        , 0.98410004, 0.9888386 , 0.99092865,
#         0.99997663, 0.9921643 , 0.98836446, 0.98893267, 0.9952733 ,
#         1.0005835 ],
#        [0.99744415, 1.0022092 , 1.        , 0.99455726, 1.0028145 ,
#         1.0022593 , 1.        , 0.9868977 , 1.0020974 , 0.9945862 ,
#         1.0000045 , 0.99165475, 1.0000408 , 0.99448085, 0.99189025,
#         0.9932615 ],
#        [1.006753  , 0.98759675, 1.        , 0.9805351 , 0.99248266,
#         1.0092853 , 1.        , 0.987148  , 1.0018992 , 0.9816809 ,
#         0.99999726, 0.9863404 , 1.0033331 , 1.0004609 , 0.9905585 ,
#         0.9896749 ],
#        [0.99722445, 1.0029144 , 1.        , 1.0018911 , 1.0013187 ,
#         0.9966294 , 1.        , 1.0039843 , 0.99926066, 0.9999422 ,
#         1.0000001 , 0.9953739 , 0.99887615, 0.99312794, 0.9962585 ,
#         1.0050575 ],
#        [0.9901969 , 1.000309  , 1.        , 0.99776334, 1.0049118 ,
#         1.0003251 , 1.        , 1.0078433 , 0.9916872 , 0.99692917,
#         0.9999989 , 0.9752253 , 0.98781395, 0.99156284, 0.99399614,
#         0.9974087 ],
#        [1.003198  , 0.9937376 , 1.        , 0.95616794, 1.0006628 ,
#         0.9878776 , 1.        , 0.9761931 , 0.97458965, 0.9916449 ,
#         1.000015  , 0.99095786, 1.0066142 , 0.9986258 , 1.0120027 ,
#         0.99466383],
#        [0.98816967, 0.9902908 , 1.        , 0.9945672 , 0.99097073,
#         0.9705034 , 1.        , 0.9643659 , 0.98326445, 0.99079496,
#         0.9999989 , 0.9866124 , 1.0106227 , 1.0034282 , 1.009979  ,
#         0.9850868 ],
#        [0.99415976, 1.001745  , 1.        , 0.9880259 , 0.9881918 ,
#         0.9920173 , 1.        , 0.9946818 , 0.9995197 , 0.9987293 ,
#         1.0000241 , 0.9982217 , 0.9953801 , 0.9958167 , 1.0014321 ,
#         0.9944013 ],
#        [0.9974701 , 0.9996289 , 1.        , 0.9951424 , 1.0071241 ,
#         1.0008367 , 1.        , 1.0103008 , 1.0017811 , 0.9985561 ,
#         1.        , 0.99546665, 0.9891649 , 0.9829301 , 0.9950951 ,
#         1.0040634 ],
#        [0.9971157 , 1.0032948 , 1.        , 0.99420285, 0.9906694 ,
#         0.9943884 , 1.        , 1.0017251 , 1.005197  , 1.0021331 ,
#         0.9999972 , 0.99589854, 0.9995191 , 0.9981127 , 0.9996032 ,
#         1.0016143 ],
#        [0.99923086, 0.9919268 , 1.        , 0.9959335 , 0.99584955,
#         1.0077654 , 1.        , 0.9980004 , 1.0016446 , 0.99517417,
#         1.0000039 , 0.9884662 , 0.99603486, 0.9981255 , 0.99633044,
#         0.99634016]], dtype=float32)
