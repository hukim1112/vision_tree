# %%
import treelib
import numpy as np
import plotly

# %%
L4 = np.load("0-17.npy")
L3 = np.load("0-12.npy")
L2 = np.load("0-7.npy")
L1 = np.load("0-2.npy")

# %%
L4
# Out:
# array([[1.23019   , 1.        , 1.        ],
#        [0.91241556, 1.        , 1.        ],
#        [1.        , 1.        , 1.        ],
#        [0.4975508 , 1.        , 1.        ],
#        [0.60684067, 1.        , 1.        ],
#        [1.4255639 , 1.        , 1.        ],
#        [1.        , 1.        , 1.        ],
#        [0.6344141 , 1.        , 1.        ],
#        [1.0628511 , 1.        , 1.        ],
#        [0.5424139 , 1.        , 1.        ],
#        [1.        , 1.        , 1.        ],
#        [0.9618053 , 1.        , 1.        ],
#        [1.0923344 , 1.        , 1.        ],
#        [1.2583965 , 1.        , 1.        ],
#        [1.1799952 , 1.        , 1.        ],
#        [1.1147056 , 1.        , 1.        ]], dtype=float32)

# %%
L3
# Out:
# array([[0.98997426, 1.0003173 , 1.0034837 , 0.9944396 , 1.0014334 ,
#         1.0069445 , 1.0038971 , 1.001172  , 0.99785477, 0.99479216,
#         1.0033149 , 0.98414844, 0.99495775, 0.99093825, 0.9943949 ,
#         1.007481  ],
#        [0.9967013 , 1.0061226 , 1.0063326 , 0.9990567 , 1.0042646 ,
#         0.9956881 , 0.99881124, 1.0012864 , 0.9989706 , 0.9975655 ,
#         0.9988186 , 0.99060893, 0.9958756 , 0.9911469 , 0.9870343 ,
#         1.0000308 ],
#        [0.9988893 , 1.0014052 , 1.0047272 , 0.99498177, 0.97638285,
#         0.9966901 , 1.0008861 , 0.9954263 , 0.99654335, 1.0053751 ,
#         1.002977  , 1.0188581 , 1.003592  , 1.005287  , 0.98524785,
#         0.9953347 ],
#        [1.0024799 , 1.0065767 , 0.99380106, 0.99866503, 0.9853351 ,
#         0.9805012 , 1.0146228 , 0.9979736 , 0.9959573 , 0.99917746,
#         1.0088868 , 1.0283144 , 0.9971314 , 1.0047349 , 1.0052165 ,
#         0.9989192 ],
# ...

# %%
L2
# Out:
# array([[1.0012693 , 1.0014243 , 1.0020896 , 1.0005615 , 0.9977392 ,
#         0.9989275 , 0.9963601 , 0.99746794, 1.0002438 , 0.99866045,
#         0.99490637, 0.9993131 , 1.0011848 , 1.0007933 , 0.9976446 ,
#         0.9973708 ],
#        [0.9999025 , 0.99665314, 0.9993857 , 0.99945307, 0.99755573,
#         0.99485695, 0.9976157 , 0.99700826, 0.99986106, 0.9972978 ,
#         0.99865204, 1.0008284 , 0.9971712 , 1.0029755 , 1.000264  ,
#         0.9978562 ],
#        [0.9996513 , 0.9997124 , 1.0003723 , 0.99979895, 0.9997655 ,
#         1.0001074 , 1.00046   , 1.0002986 , 0.999371  , 0.99917644,
#         0.999937  , 0.99969316, 1.0001069 , 0.9996693 , 0.99989086,
#         0.9998084 ],
#        [0.9994862 , 1.001096  , 1.0007854 , 0.99970555, 0.9988636 ,
#         1.0013705 , 0.99978864, 0.9972279 , 0.99969107, 0.9987537 ,
#         0.99771726, 0.99895966, 1.0011442 , 0.999685  , 1.0011097 ,
#         0.9987801 ],
# ...
